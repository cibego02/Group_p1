# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.signal import butter,freqs,argrelextrema,filtfilt,find_peaks
import plotly.graph_objects as go

# %%
file_name = "C:\\Users\\Utente\\OneDrive\\ITS machine Learning\\Project Work\\Progetto 2\\Data\\29-09-2021 114940.txt"

# %%
df = pd.read_table(file_name)
df
# Out:
#            Timestamp    Acc.X    Acc.Y     Acc.Z  Gyro.X  Gyro.Y  Gyro.Z  \
# 0      1632916180016  569.496  -34.648   696.864   -2.87   -3.50    0.00
# 1      1632916180026  -12.688 -284.504  1119.472  -11.55    5.18  -34.09
# 2      1632916180036   25.376 -303.536   859.368  -23.59   27.86  -14.84
# 3      1632916180046  184.952 -359.168   801.784  -15.96   26.81   -0.77
# 4      1632916180056  354.288 -372.344   811.544  -16.38   18.83   14.84
# ...              ...      ...      ...       ...     ...     ...     ...
# 10705  1632916287170  151.768  -17.568   986.736   -1.89    0.56   -1.26
# 10706  1632916287180  159.088  -16.104  1001.376   -3.22    1.75    0.56
# 10707  1632916287190  162.992  -12.688  1012.112   -3.08    1.68   -0.35
# 10708  1632916287200  166.896   -9.760  1021.384   -1.47    2.31   -1.61
# 10709  1632916287210  156.160   -6.832   992.592    1.54    1.75   -3.57
#
#        Magn.X  Magn.Y  Magn.Z  ...  P.9  P.10  P.11  P.12  P.13  P.14  P.15  \
# ...

# %%
df["Time"] = df.index/100

# %%
df1 = df[["Time","PPG_RED.","PPG_IR."]].copy()

# %%
df1
# Out:
#          Time  PPG_RED.  PPG_IR.
# 0        0.00      6570     5593
# 1        0.01      6540     5614
# 2        0.02      6555     5591
# 3        0.03      6536     5596
# 4        0.04      6545     5591
# ...       ...       ...      ...
# 10705  107.05    147298   232872
# 10706  107.06    146654   231040
# 10707  107.07    145651   227911
# 10708  107.08    144333   224026
# 10709  107.09    142450   219053
#
# [10710 rows x 3 columns]

# %%
fig = px.line( title = "PPG" )
fig.add_scatter(x=df1["Time"], y =df1["PPG_IR."],name= "PPG IR")
fig.add_scatter(x=df1["Time"], y =df1["PPG_RED."], name = "PPG RED")
fig.update_layout(legend_title_text ="PPG")

fig.show()
